# %% [markdown]
# # Object-Oriented-Programming (OOP)

# %% [markdown]
# ## Tasks Today:
#
#
#
# 1) <b>Creating a Class (Initializing/Declaring)</b> <br>
# 2) <b>Using a Class (Instantiating)</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Creating One Instance <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Creating Multiple Instances <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) In-Class Exercise #1 - Create a Class 'Car' and instantiate three different makes of cars <br>
# 3) <b>The \__init\__() Method</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) The 'self' Attribute <br>
# 4) <b>Class Attributes</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Initializing Attributes <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Setting an Attribute Outside of the \__init\__() Method <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Setting Defaults for Attributes <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Accessing Class Attributes <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Changing Class Attributes <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) In-Class Exercise #2 - Add a color and wheels attribute to your 'Car' class <br>
# 5) <b>Class Methods</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Creating <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Calling <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Modifying an Attribute's Value Through a Method <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Incrementing an Attribute's Value Through a Method <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) In-Class Exercise #3 - Add a method that prints the cars color and wheel number, then call them <br>
# 6) <b>Inheritance</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Syntax for Inheriting from a Parent Class <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) The \__init\__() Method for a Child Class (super()) <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Defining Attributes and Methods for the Child Class <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Method Overriding <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) In-Class Exercise #4 - Create a class 'Ford' that inherits from 'Car' class and initialize it as a Blue Ford Explorer with 4 wheels using the super() method <br>
# 7) <b>Classes as Attributes</b> <br>
# 8) <b>Exercises</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Exercise #1 - Turn the shopping cart program from yesterday into an object-oriented program <br>

# %% [markdown]
# ## Creating a Class (Initializing/Declaring)
# <p>When creating a class, function, or even a variable you are initializing that object. Initializing and Declaring occur at the same time in Python, whereas in lower level languages you have to declare an object before initializing it. This is the first step in the process of using a class.</p>

# %%
class Car():
    wheels = 4
    color = 'blue'

# %% [markdown]
# ## Using a Class (Instantiating)
# <p>The process of creating a class is called <i>Instantiating</i>. Each time you create a variable of that type of class, it is referred to as an <i>Instance</i> of that class. This is the second step in the process of using a class.</p>

# %% [markdown]
# ##### Creating One Instance

# %%
ford = Car()
print(ford.wheels)
# Out:
# 4

# %% [markdown]
# ##### Creating Multiple Instances

# %%
chevy = Car()
honda = Car()
porsche = Car()

print(type(porsche.color))
print(porsche.bumper)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 6>()
#       3 porsche = Car()
#       5 print(type(porsche.color))
# ----> 6 print(porsche.bumper)
#
# AttributeError: 'Car' object has no attribute 'bumper'

# %% [markdown]
# ##### In-Class Exercise #1 - Create a Class 'Car' and Instantiate three different makes of cars

# %%
class Car():
    doors = 4
    color = 'black'
    wheels = 4

buic = Car()
ford = Car()
jeep = Car()

print(buic.wheels)
print(jeep.doors)
print(ford.color)
# Out:
# 4
# 4
# black

# %% [markdown]
# ## The \__init\__() Method <br>
# <p>This method is used in almost every created class, and called only once upon the creation of the class instance. This method will initialize all variables needed for the object.</p>

# %%
class Car():
  engine = '4.7L' # constant attribute

  def __init__(self, wheels, color):
    self.wheels = wheels
    self.color = color

ford = Car(4, 'red')
chevy = Car(6, 'black')

print(ford.wheels)
print(chevy.wheels)
# Out:
# 4
# 6

# %% [markdown]
# ##### The 'self' Attribute <br>
# <p>This attribute is required to keep track of specific instance's attributes. Without the self attribute, the program would not know how to reference or keep track of an instance's attributes.</p>

# %%
# see above

# %% [markdown]
# ## Class Attributes <br>
# <p>While variables are inside of a class, they are referred to as attributes and not variables. When someone says 'attribute' you know they're speaking about a class. Attributes can be initialized through the init method, or outside of it.</p>

# %% [markdown]
# ##### Initializing Attributes

# %%
# see above

class Toy():
  kind = 'car'

  def __init__(self, rooftop, horn, wheels = 4):
    self.rooftop = rooftop
    self.horn = horn
    self.wheels = wheels

tonka_truck = Toy(1,1)
hotwheels_car = Toy(2,3,8)

# %% [markdown]
# ##### Accessing Class Attributes

# %%
# See Above
print(tonka_truck.horn)
print(hotwheels_car.wheels)
# Out:
# 1
# 8

# %% [markdown]
# ##### Setting Defaults for Attributes

# %%
class Car():
    engine = '4.7L'
    
    def __init__(self, wheels):
      self.wheels = wheels
      self.color = 'Blue' 

honda = Car(4)
print(honda.color)
print(honda.wheels)
honda.engine = '5.4L'
# Out:
# Blue
# 4
# <__main__.Car object at 0x7f6e57826050>

# %% [markdown]
# ##### Changing Class Attributes <br>
# <p>Keep in mind there are global class attributes and then there are attributes only available to each class instance which won't effect other classes.</p>

# %%
jeep = Car()

print(f'Before change: {jeep.color}')

jeep.color = 'White'

print(f'\nAfter change: {jeep.color}')
print(honda.color)
# Out:
# Before change: black
#
# After change: White
# blue

# %% [markdown]
# ##### In-Class Exercise #2 - Add a doors and seats attribute to your 'Car' class then print out two different instances with different doors and seats

# %%
class Car():
    
    def __init__(self, doors, seats):
        self.doors = doors
        self.seats = seats
        
toyota = Car(4, 8)
jeep = Car(6, 6)

print(f'Toyota seats: {toyota.seats} and Toyota doors: {toyota.doors}')
print(f'Jeep seats: {jeep.seats} and Jeep doors {jeep.doors}')
# Out:
# Toyota seats: 8 and Toyota doors: 4
# Jeep seats: 6 and Jeep doors 6

# %% [markdown]
# ## Class Methods <br>
# <p>While inside of a class, functions are referred to as 'methods'. If you hear someone mention methods, they're speaking about classes. Methods are essentially functions, but only callable on the instances of a class.</p>

# %% [markdown]
# ##### Creating

# %%
class ShoppingBag():
    
    """
        The ShopppingBag class will be handels, capacity, 
        and items to place inside.
        
        Attributes for the class:
        - handels: expected to be an intiger
        - capacity: expected to be a string Or and intiger
        - items: expected to be a list    
    """
    
    def __init__(self, handels, capacity, items):
        self.handels = handels
        self.capacity = capacity
        self.items = items
        
    def showShoppingBag(self):
        print("You have items in your bag!")
        for item in self.items:
            print(item)
            
    def showCapacity(self):
        print(f'Your capacity is: {self.capacity}')
        
    def addToShoppingBag(self):
        products = input('What would you like to add? ')
        self.items.append(products)
        
    def changeBagCapacity(self, capacity):
        self.capacity = capacity
        
    def increaseCapacity(self, changed_capacity = 10):
        if self.capacity == isinstance(self.capacity, str):
            print("We can't add that here")
        else:
            self.capacity += changed_capacity

# %% [markdown]
# ##### Calling

# %%
# See Above

wholeFoods_bag = ShoppingBag(2, 10, [])

def run():
    while True:
        response = input('What do you want to do? add/show/quit ')
        
        if response.lower() == 'quit':
            wholeFoods_bag.showShoppingBag()
            print('Thanks for shopping!')
            break
        elif response.lower() == 'add':
            wholeFoods_bag.addToShoppingBag()
        elif response.lower() == 'show':
            wholeFoods_bag.showShoppingBag()
        else:
            print('Try another command')
            
run()
# Out:
# What do you want to do? add/show/quit add
# What would you like to add? pinnaple
# What do you want to do? add/show/quit add
# What would you like to add? grapes
# What do you want to do? add/show/quit add
# What would you like to add? coffee
# What do you want to do? add/show/quit show
# You have items in your bag!
# pinnaple
# grapes
# coffee
# What do you want to do? add/show/quit another
# Try another command
# What do you want to do? add/show/quit quit
# You have items in your bag!
# pinnaple
# grapes
# coffee
# Thanks for shopping!

# %% [markdown]
# ##### Modifying an Attribute's Value Through a Method

# %%
wholeFoods_bag.showCapacity()
print('Capacity after the change...')
wholeFoods_bag.changeBagCapacity(40)
wholeFoods_bag.showCapacity()
# Out:
# Your capacity is: 10
# Capacity after the change...
# Your capacity is: 40

# %% [markdown]
# ##### Incrementing an Attribute's Value Through a Method

# %%
wholeFoods_bag.showCapacity()
print('After increase:')
wholeFoods_bag.increaseCapacity()
wholeFoods_bag.showCapacity()
# Out:
# Your capacity is: 40
# After increase:
# Your capacity is: 50

# %% [markdown]
# ##### In-Class Exercise #3 - Add a method that takes in three parameters of year, doors and seats and prints out a formatted print statement with make, model, year, seats, and doors

# %%
# Create class with 2 paramters inside of the __init__ which are make and model
class Car():
    
    def __init__(self, make, model):
        self.make = make
        self.model = model
    def makeOfCar(self):
        print('Ford')
        
    def modelOfCar(self):
        print('Explorer')
# Inside of the Car class create a method that has 4 parameter in total (self,year,door,seats)
    def items(self, year, door, seats):
        self.year = year
        self.door = door
        self.seats = seats
        print(2019)
        print(4)
        print(5)
        
    def year(self, year):
        self.year = year
        print(2019)
    def door(self, door):
        self.door = door
        print(4)
    def seats(self, seats):
        self.seats = seats
        print(5)
            
ford = Car('Ford', 'Exploror')
def vroom():
    ford.makeOfCar()
    ford.modelOfCar()
#     ford.items('2019', '4', '5')
    ford.year('2019')
    ford.door('4')
    ford.seats('5')
    
vroom()

print(f'This car is from {ford.year} and is a {ford.make} {ford.model} and has {ford.door} doors and {ford.seats} seats.')

# Output: This car is from 2019 and is a Ford Expolorer and has 4 doors and 5 seats
# Out:
# Ford
# Explorer
# 2019
# 4
# 5
# This car is from 2019 and is a Ford Exploror and has 4 doors and 5 seats.

# %% [markdown]
# ## Inheritance <br>
# <p>You can create a child-parent relationship between two classes by using inheritance. What this allows you to do is have overriding methods, but also inherit traits from the parent class. Think of it as an actual parent and child, the child will inherit the parent's genes, as will the classes in OOP</p>

# %% [markdown]
# ##### Syntax for Inheriting from a Parent Class

# %%
class Animal():
    acceleration = 9.8
    
    def __init__(self, name, species, legs = 4):
        self.name = name
        self.species = species
        self.legs =legs
        
    def makeSound(self):
        print('Make some generic sound')
        
class Dog(Animal):
    speed = 15
    
    def printInfo(self):
        print(f'The dog has a speed of {self.speed} mph and {self.acceleration}')
        
class Mutt(Dog):
    color = "Tan"
    
    def __init__(self, name, species, eye_color, legs = 4):
        Dog.__init__(self, name, species, legs)
        self.eye_color = eye_color
        
    def makeSound(self):
        noise = 'Bark'
        return noise
    
lassie = Dog('lassie', 'Dog')
basic_animal = Animal('generic animal name', 'generic animal species')
buster = Mutt('Buster', 'Mutt', 'Brown')

print(buster.makeSound())
print(lassie.makeSound())
print(buster.acceleration)
print(buster.speed)
# Out:
# Bark
# Make some generic sound
# None
# 9.8
# 15

# %% [markdown]
# ##### The \__init\__() Method for a Child Class - super()

# %%
class Puppy(Dog):
    color = 'Black and Brown'
    
    def __init__(self, name, species, eye_color, legs = 4):
        super().__init__(name, species, legs)
        self.eye_color = eye_color
        
    def makeSound(self):
        noise = 'Bark'
        return noise
    
lassie = Dog('lassie', 'Dog')
basic_animal = Animal('generic animal name', 'generic animal species')
buster = Mutt('Buster', 'Mutt', 'Brown')

print(buster.makeSound())
print(lassie.makeSound())
print(buster.acceleration)
print(buster.speed)
# Out:
# Bark
# Make some generic sound
# None
# 9.8
# 15

# %% [markdown]
# ##### Defining Attributes and Methods for the Child Class

# %%
# See Above

# %% [markdown]
# ##### Method Overriding

# %%
# See Above

# %% [markdown]
# ## Classes as Attributes <br>
# <p>Classes can also be used as attributes within another class. This is useful in situations where you need to keep variables locally stored, instead of globally stored.</p>

# %%
class Battery():
    volts = 7.8
    
    def __init__(self, cells):
        self.cells = cells
        
class Car():
    def __init__(self, year, make, model, battery):
        self.year = year
        self.make = make
        self.model = model
        self.battery = battery
        
    def printinfo(self):
        return f'{self.year} {self.make} {self.model} {self.battery.cells}'
    
my_battery = Battery(20)

tesla = Car(2019, 'Tesla', 'Model X', my_battery)

print(tesla.battery.cells)
tesla.printinfo()
# Out:
# 20
# '2019 Tesla Model X 20'

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Exercise 1 - Turn the shopping cart program from yesterday into an object-oriented program
#
# The comments in the cell below are there as a guide for thinking about the problem. However, if you feel a different way is best for you and your own thought process, please do what feels best for you by all means.

# %%
# Create a class called cart that retains items and has methods to add, remove, and show
def my_dict(item_name, item_price):
    shoppingCart = {'item': item_name, 'price': item_price}
    return shoppingCart

class ShoppingCart():
    
    def __init__(self, items):
        self.items = items
    
    def addToShoppingCart(self):
        Bag = input('What would you like to add? ')
        self.items.append(Bag)
    
    def ShowCart(self):
        if self.items == 0:
            print('You have no items in your cart :(!')
        else:
            print("You have items in your cart :)")
            for items in self.items:
                print(items)
   
    def removeFromCart(self):
        bags = Bag(input())
            
walmart_Bag = ShoppingCart([])

def mylist1():
    while True:
        response = input('Do you want to add/delete/show/quit your shopping cart? ')
        if response.lower() == 'quit':
            break
        elif response.lower() == 'add':
            walmart_Bag.addToShoppingCart()
        elif response.lower() == 'delete':
            walmart_Bag.removeFromCart()
        elif response.lower() == 'show':
            walmart_Bag.ShowCart()
        else:
            print('That is not a valid option. Please choose another')
mylist1()
# Out:
# Do you want to add/delete/show/quit your shopping cart? add
# What would you like to add? something
# Do you want to add/delete/show/quit your shopping cart? delete
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 41>()
#      39         else:
#      40             print('That is not a valid option. Please choose another')
# ---> 41 mylist1()
#
# Input In [11], in mylist1()
#      34     walmart_Bag.addToShoppingCart()
#      35 elif response.lower() == 'delete':
# ---> 36     walmart_Bag.removeFromCart()
#      37 elif response.lower() == 'show':
#      38     walmart_Bag.ShowCart()
#
# Input In [11], in ShoppingCart.removeFromCart(self)
#      23 def removeFromCart(self):
# ---> 24     bags = Bag(input())
#
# NameError: name 'Bag' is not defined

# %% [markdown]
# ### Exercise 2 - Write a Python class which has two methods get_String and print_String. get_String accept a string from the user and print_String print the string in upper case

# %%
# response = input('Tell me sometthing ')
class WaterBottle():
    def __init__(self):
        self.str1 = ""

    def get_String(self):
        self.str1 = input('Tell me something ')

    def print_String(self):
        print(self.str1.upper())

str1 = WaterBottle()
str1.get_String()
str1.print_String()
# Out:
# Tell me something Coding is great
# CODING IS GREAT
